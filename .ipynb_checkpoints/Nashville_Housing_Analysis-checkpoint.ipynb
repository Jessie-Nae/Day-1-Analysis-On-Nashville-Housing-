# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('Nashville Housing.csv')

# %% [markdown]
# #### Q1.. Does 'Acreage' affect the 'sale price' of the property??(WHO)
# #### Q2.. What is the most expensive property and why is it so??
# #### Q3.. How many properties were sold each year??
# #### Q4.. Was there a circumstance when the 'total price' is greater than the  'sale price' of a property??
# #### Q5.. What is the relationship between 'acreage' and 'land value'??
# #### Q6.. What is the difference between 'the year the property was built ' and 'the year the property was sold'??
# #### Q7.. What is the relationship between 'bedrooms', 'fullbath' and 'halfbath'??

# %%
data.head(60)
# Out:
#     UniqueID           ParcelID            LandUse  \
# 0        2045   007 00 0 125.00      SINGLE FAMILY
# 1       16918   007 00 0 130.00      SINGLE FAMILY
# 2       54582   007 00 0 138.00      SINGLE FAMILY
# 3       43070   007 00 0 143.00      SINGLE FAMILY
# 4       22714   007 00 0 149.00      SINGLE FAMILY
# 5       18367   007 00 0 151.00      SINGLE FAMILY
# 6       19804   007 14 0 002.00      SINGLE FAMILY
# 7       54583   007 14 0 024.00      SINGLE FAMILY
# 8       36500   007 14 0 026.00      SINGLE FAMILY
# 9       19805   007 14 0 034.00      SINGLE FAMILY
# 10      29467  007 14 0A 024.00      SINGLE FAMILY
# 11      10754  007 14 0A 027.00      SINGLE FAMILY
# 12      34751  007 14 0B 010.00  RESIDENTIAL CONDO
# 13       4512   007 15 0 002.00      SINGLE FAMILY
# 14      16919   007 15 0 003.00      SINGLE FAMILY
# 15      16920   007 15 0 004.00      SINGLE FAMILY
# 16      51967   007 15 0 008.00      SINGLE FAMILY
# 17      28155   007 15 0 014.00      SINGLE FAMILY
# 18       8899   007 15 0 020.00      SINGLE FAMILY
# 19       4513   007 15 0 031.00      SINGLE FAMILY
# 20      27161   007 15 0 044.00      SINGLE FAMILY
# 21      46859   007 15 0 048.00      SINGLE FAMILY
# 22       5802   007 15 0 052.00      SINGLE FAMILY
# 23      36501   010 00 0 045.00      SINGLE FAMILY
# 24       8900   010 00 0 052.00      SINGLE FAMILY
# 25      48716  011 15 0A 004.00      SINGLE FAMILY
# 26      26215   012 00 0 082.00      SINGLE FAMILY
# 27      19806   012 00 0 083.00      SINGLE FAMILY
# 28       8901   012 00 0 109.00      SINGLE FAMILY
# 29      36502   012 02 0 011.00      SINGLE FAMILY
# 30      13354   012 02 0 019.00      SINGLE FAMILY
# 31      45285   012 03 0 006.00      SINGLE FAMILY
# 32      53116   012 03 0 009.00      SINGLE FAMILY
# 33      15542   012 03 0 012.00      SINGLE FAMILY
# 34      54584   012 03 0 013.00      SINGLE FAMILY
# 35       1207   012 03 0 018.00      SINGLE FAMILY
# 36        667   012 03 0 023.00      SINGLE FAMILY
# 37      34752   012 03 0 025.00      SINGLE FAMILY
# 38      39426   015 14 0 011.00      SINGLE FAMILY
# 39      48717   015 14 0 045.00      SINGLE FAMILY
# 40      53117   015 14 0 053.00      SINGLE FAMILY
# 41      39427   015 14 0 054.00      SINGLE FAMILY
# 42       5803   015 14 0 055.00      SINGLE FAMILY
# 43       6993   015 14 0 060.00      SINGLE FAMILY
# 44      43071   015 14 0 060.00      SINGLE FAMILY
# 45      45286   015 14 0 061.00      SINGLE FAMILY
# 46       3267   015 14 0 071.00      SINGLE FAMILY
# 47      34753   015 14 0 075.00      SINGLE FAMILY
# 48      39428   016 00 0 093.00      SINGLE FAMILY
# 49      21298   016 00 0 110.00      SINGLE FAMILY
# 50      34754   016 00 0 143.00      SINGLE FAMILY
# 51      39429   016 00 0 184.00      SINGLE FAMILY
# 52       5804   016 00 0 191.00      SINGLE FAMILY
# 53      34755   016 00 0 216.00      SINGLE FAMILY
# 54      21299   018 00 0 041.00      SINGLE FAMILY
# 55       8902   018 00 0 042.00      SINGLE FAMILY
# 56       4514   018 00 0 087.00  VACANT RURAL LAND
# 57       4515   018 00 0 096.00    VACANT RES LAND
# 58       4516   018 00 0 097.00      SINGLE FAMILY
# 59      50583   018 00 0 136.00      SINGLE FAMILY
#
#                                PropertyAddress            SaleDate SalePrice  \
# 0           1808  FOX CHASE DR, GOODLETTSVILLE       April 9, 2013    240000
# 1           1832  FOX CHASE DR, GOODLETTSVILLE       June 10, 2014    366000
# 2           1864 FOX CHASE  DR, GOODLETTSVILLE  September 26, 2016    435000
# 3           1853  FOX CHASE DR, GOODLETTSVILLE    January 29, 2016    255000
# 4           1829  FOX CHASE DR, GOODLETTSVILLE    October 10, 2014    278000
# 5           1821  FOX CHASE DR, GOODLETTSVILLE       July 16, 2014    267000
# 6               2005  SADIE LN, GOODLETTSVILLE     August 28, 2014    171000
# 7           1917 GRACELAND  DR, GOODLETTSVILLE  September 27, 2016    262000
# 8        1428  SPRINGFIELD HWY, GOODLETTSVILLE     August 14, 2015    285000
# 9        1420  SPRINGFIELD HWY, GOODLETTSVILLE     August 29, 2014    340000
# 10              2209  KAYLA DR, GOODLETTSVILLE      April 14, 2015    425000
# 11         109  BAILEY VIEW CT, GOODLETTSVILLE   December 12, 2013    585000
# 12             1900  TINNIN RD, GOODLETTSVILLE       July 13, 2015    190000
# 13           629  GAYLEMORE DR, GOODLETTSVILLE        June 7, 2013    189900
# 14           633  GAYLEMORE DR, GOODLETTSVILLE       June 30, 2014    157500
# 15           637  GAYLEMORE DR, GOODLETTSVILLE       June 30, 2014    247400
# 16              1976 SADIE  LN, GOODLETTSVILLE       July 15, 2016    211500
# 17           644  GAYLEMORE DR, GOODLETTSVILLE      March 31, 2015    185900
# 18           1921  NORMERLE DR, GOODLETTSVILLE    October 11, 2013    349900
# 19           1916  NORMERLE DR, GOODLETTSVILLE       June 28, 2013    192500
# 20          2050  GRACELAND DR, GOODLETTSVILLE   February 10, 2015    279900
# 21          2034  GRACELAND DR, GOODLETTSVILLE      April 14, 2016    379900
# 22              811  BENTON CT, GOODLETTSVILLE        July 8, 2013    192500
# 23          331  VIEW RIDGE DR, GOODLETTSVILLE     August 31, 2015    193500
# 24          361  VIEW RIDGE DR, GOODLETTSVILLE    October 21, 2013    172400
# 25            119 LAKESIDE  DR, GOODLETTSVILLE        May 31, 2016    435000
# 26  8154  OLD SPRINGFIELD PIKE, GOODLETTSVILLE    January 26, 2015    162500
# 27  8158  OLD SPRINGFIELD PIKE, GOODLETTSVILLE      August 1, 2014    235000
# 28  8136  OLD SPRINGFIELD PIKE, GOODLETTSVILLE    October 11, 2013    225000
# 29       1334  SPRINGFIELD HWY, GOODLETTSVILLE     August 27, 2015    271000
# 30       1412  SPRINGFIELD HWY, GOODLETTSVILLE      March 18, 2014    359900
# 31           612  GAYLEMORE DR, GOODLETTSVILLE      March 11, 2016    276500
# 32         2013 SUNNYSLOPE  LN, GOODLETTSVILLE     August 29, 2016    271500
# 33          600  SUNNYSLOPE CT, GOODLETTSVILLE        May 14, 2014    205900
# 34          604 SUNNYSLOPE  CT, GOODLETTSVILLE  September 23, 2016    228000
# 35          609  SUNNYSLOPE CT, GOODLETTSVILLE      March 15, 2013    160000
# 36           621  GAYLEMORE DR, GOODLETTSVILLE    February 8, 2013    129900
# 37           613  GAYLEMORE DR, GOODLETTSVILLE       July 17, 2015    230000
# 38                3128  UNION HILL RD, JOELTON     October 1, 2015     90000
# 39                      7515 GARY  RD, JOELTON        May 27, 2016    160000
# 40                    7620 GERALD  DR, JOELTON      August 8, 2016    195900
# 41                    7624  GERALD DR, JOELTON     October 9, 2015    122431
# 42                    7628  GERALD DR, JOELTON       July 12, 2013    119900
# 43                  3113  MILLIKEN DR, JOELTON     August 20, 2013    145000
# 44                  3113  MILLIKEN DR, JOELTON    January 15, 2016    160000
# 45                  3117  MILLIKEN DR, JOELTON      March 18, 2016    169900
# 46                    3107  MARGIE DR, JOELTON        May 10, 2013    103500
# 47                    3124  MARGIE DR, JOELTON       July 31, 2015    184000
# 48         2466  UNION HILL RD, GOODLETTSVILLE    October 13, 2015    165000
# 49         7221  APPLE VIEW DR, GOODLETTSVILLE  September 24, 2014    290000
# 50         7104  LAMA TERRA DR, GOODLETTSVILLE        July 6, 2015    260000
# 51         7143  LAMA TERRA DR, GOODLETTSVILLE     October 9, 2015    200000
# 52         7175  LAMA TERRA DR, GOODLETTSVILLE       July 29, 2013    165000
# 53        6912  RIDGERUNNER CT, GOODLETTSVILLE       July 10, 2015    230000
# 54           334  MONCRIEF AVE, GOODLETTSVILLE   September 2, 2014    147000
# 55           330  MONCRIEF AVE, GOODLETTSVILLE    October 25, 2013    154900
# 56        0  BRICK CHURCH PIKE, GOODLETTSVILLE       June 28, 2013    250000
# 57        0  BRICK CHURCH PIKE, GOODLETTSVILLE       June 28, 2013    250000
# 58      235  BRICK CHURCH PIKE, GOODLETTSVILLE       June 28, 2013    250000
# 59               522 UTLEY  DR, GOODLETTSVILLE       June 10, 2016    305000
#
#       LegalReference SoldAsVacant  \
# 0   20130412-0036474           No
# 1   20140619-0053768           No
# 2   20160927-0101718           No
# 3   20160129-0008913           No
# 4   20141015-0095255           No
# 5   20140718-0063802           No
# 6   20140903-0080214           No
# 7   20161005-0105441           No
# 8   20150819-0083440           No
# 9   20140909-0082348           No
# 10  20150415-0033442           No
# 11  20131227-0130352           No
# 12  20150717-0069947           No
# 13  20130612-0059715           No
# 14  20140702-0058050           No
# 15  20140630-0057267           No
# 16  20160720-0074793           No
# 17  20150402-0029022           No
# 18  20131018-0109102           No
# 19  20130711-0071698           No
# 20  20150212-0012993           No
# 21  20160418-0036715           No
# 22  20130712-0072376           No
# 23  20150903-0090036           No
# 24  20131030-0112723           No
# 25  20160602-0055827           No
# 26  20150127-0007529           No
# 27  20140808-0071505           No
# 28  20131022-0110073           No
# 29  20150901-0088477           No
# 30  20140321-0023358           No
# 31  20160317-0025384           No
# 32  20160831-0091434           No
# 33  20140529-0045974           No
# 34  20160927-0101636           No
# 35  20130319-0026986           No
# 36  20130215-0015687           No
# 37  20150721-0071254           No
# 38  20151006-0101964           No
# 39  20160606-0056507           No
# 40  20160810-0083381           No
# 41  20151013-0103951           No
# 42  20130718-0074201           No
# 43  20130821-0088382           No
# 44  20160119-0004923           No
# 45  20160413-0035454           No
# 46  20130513-0047997           No
# 47  20150803-0076727           No
# 48  20151014-0104536           No
# 49  20141009-0093665           No
# 50  20150708-0066261           No
# 51  20151013-0103879           No
# 52  20130729-0078604           No
# 53  20150713-0067794           No
# 54  20140908-0081941           No
# 55  20131028-0111690           No
# 56  20130709-0070947           No
# 57  20130709-0070947           No
# 58  20130709-0070947           No
# 59  20160614-0060196           No
#
#                                             OwnerName  \
# 0                           FRAZIER, CYRENTHA LYNETTE
# 1                             BONER, CHARLES & LESLIE
# 2                           WILSON, JAMES E. & JOANNE
# 3                            BAKER, JAY K. & SUSAN E.
# 4                  POST, CHRISTOPHER M. & SAMANTHA C.
# 5                         FIELDS, KAREN L. & BRENT A.
# 6               HINTON, MICHAEL R. & CYNTHIA M. MOORE
# 7                             BAILOR, DARRELL & TAMMY
# 8                       ROBERTS, MISTY L. & ROBERT M.
# 9                                LEE, JEFFREY & NANCY
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                   URRUTIA, CARLOS MIGUEL & REBECCA
# 14                   SALDANA, ALMA J. & EDWARD A., II
# 15                      MCKINNEY, ROBERT K. & BETH E.
# 16                       MILLER, JAMES L. & EILEEN T.
# 17                                   SANDAGE, LEAH S.
# 18                                       VAUGHN, JOHN
# 19        PARKS, KRISTEN LEIGH & WILLIAMS, PAMELA KAY
# 20                      ANGELL, MARGO G. & CHARLES D.
# 21                     DOSS, GLEN KEVIN & ANGELA DAWN
# 22                        BRAKE, MICHAEL E. & ERIN L.
# 23  BENJAMIN, DAVID AND LINDA REVOCABLE LIVING TRU...
# 24                       WILLIAMS, JOSEPH D. & AUDREY
# 25                                                NaN
# 26                               SMITH, JAMES M., JR.
# 27                              HOWARD, MARK & LUANNE
# 28                       DAWSON, KENNETH D. & NATALIE
# 29                            NAUERT, MARK II & SARAH
# 30                                 BATSON, JEFFERY L.
# 31                     ADAMS, ALEXANDER J. & JENNIFER
# 32          ARNOLD, RACHEL & SPARKMAN, JIMMY & SANDRA
# 33                          SKAGGS, BROCK A. & DENISE
# 34                                   RED THUNDER, LLC
# 35                   O'CONNELL, JAMES L. & VANESSA R.
# 36                                      TUDERS, KEVIN
# 37              BOISE, LINDSEY J. & BURDEN, GINGER E.
# 38  IBARRA-ROMERO, GREGORIO & REGINO, EVEIDA ACIAD...
# 39                                PORTER, BRIAN KELLY
# 40                                     TEMPLE, LORENE
# 41                                  STEWART, DONNA D.
# 42                      PROULX, JENNIFER L. & JESSICA
# 43                               SMITH, HOLLI NICHOLE
# 44                               SMITH, HOLLI NICHOLE
# 45                                    DISMANG, JEREMY
# 46                                     DOWNS, JESSICA
# 47                                       MURRY, SHAWN
# 48                     HARRISON, JASON C. & AMANDA D.
# 49                       MILLER, WILLIAM B. & RETA A.
# 50                            GIGEAR, DAVID & DESIREE
# 51                   MORELOCK, WALTER L. JR & LISA D.
# 52                          WALL, COREY D. & LAURA A.
# 53                      SHRUM, AMANDA & HARTLEY, RYAN
# 54                         DAHLHAUSER, ANDREW FRANCIS
# 55                 BRANNING, OLIVER MACK & MICHELE M.
# 56                    BUCHANAN, DONALD W. & SANDRA R.
# 57                    BUCHANAN, DONALD W. & SANDRA R.
# 58                    BUCHANAN, DONALD W. & SANDRA R.
# 59                                     THEDE, ADAM S.
#
#                                       OwnerAddress  Acreage  \
# 0           1808  FOX CHASE DR, GOODLETTSVILLE, TN     2.30
# 1           1832  FOX CHASE DR, GOODLETTSVILLE, TN     3.50
# 2           1864  FOX CHASE DR, GOODLETTSVILLE, TN     2.90
# 3           1853  FOX CHASE DR, GOODLETTSVILLE, TN     2.60
# 4           1829  FOX CHASE DR, GOODLETTSVILLE, TN     2.00
# 5           1821  FOX CHASE DR, GOODLETTSVILLE, TN     2.00
# 6               2005  SADIE LN, GOODLETTSVILLE, TN     1.03
# 7           1917  GRACELAND DR, GOODLETTSVILLE, TN     1.03
# 8        1428  SPRINGFIELD HWY, GOODLETTSVILLE, TN     1.67
# 9        1420  SPRINGFIELD HWY, GOODLETTSVILLE, TN     1.30
# 10                                             NaN      NaN
# 11                                             NaN      NaN
# 12                                             NaN      NaN
# 13           629  GAYLEMORE DR, GOODLETTSVILLE, TN     1.07
# 14           633  GAYLEMORE DR, GOODLETTSVILLE, TN     1.03
# 15           637  GAYLEMORE DR, GOODLETTSVILLE, TN     1.03
# 16              2001  SADIE LN, GOODLETTSVILLE, TN     1.08
# 17           644  GAYLEMORE DR, GOODLETTSVILLE, TN     1.03
# 18           1921  NORMERLE DR, GOODLETTSVILLE, TN     1.03
# 19           1916  NORMERLE DR, GOODLETTSVILLE, TN     1.00
# 20          2050  GRACELAND DR, GOODLETTSVILLE, TN     1.28
# 21          2034  GRACELAND DR, GOODLETTSVILLE, TN     2.61
# 22              811  BENTON CT, GOODLETTSVILLE, TN     1.10
# 23          331  VIEW RIDGE DR, GOODLETTSVILLE, TN     1.69
# 24          361  VIEW RIDGE DR, GOODLETTSVILLE, TN     2.50
# 25                                             NaN      NaN
# 26  8154  OLD SPRINGFIELD PIKE, GOODLETTSVILLE, TN     2.31
# 27  8158  OLD SPRINGFIELD PIKE, GOODLETTSVILLE, TN     2.31
# 28  8136  OLD SPRINGFIELD PIKE, GOODLETTSVILLE, TN     3.71
# 29       1334  SPRINGFIELD HWY, GOODLETTSVILLE, TN     1.75
# 30       1412  SPRINGFIELD HWY, GOODLETTSVILLE, TN     1.17
# 31           612  GAYLEMORE DR, GOODLETTSVILLE, TN     1.01
# 32         2013  SUNNYSLOPE LN, GOODLETTSVILLE, TN     1.03
# 33          600  SUNNYSLOPE CT, GOODLETTSVILLE, TN     1.07
# 34          604  SUNNYSLOPE CT, GOODLETTSVILLE, TN     1.01
# 35          609  SUNNYSLOPE CT, GOODLETTSVILLE, TN     1.07
# 36           621  GAYLEMORE DR, GOODLETTSVILLE, TN     1.05
# 37           613  GAYLEMORE DR, GOODLETTSVILLE, TN     0.98
# 38                3128  UNION HILL RD, JOELTON, TN     0.93
# 39                      7515  GARY RD, JOELTON, TN     1.06
# 40                    7620  GERALD DR, JOELTON, TN     1.07
# 41                    7624  GERALD DR, JOELTON, TN     1.07
# 42                    7628  GERALD DR, JOELTON, TN     1.05
# 43                  3113  MILLIKEN DR, JOELTON, TN     0.98
# 44                  3113  MILLIKEN DR, JOELTON, TN     0.98
# 45                  3117  MILLIKEN DR, JOELTON, TN     0.98
# 46                    3107  MARGIE DR, JOELTON, TN     1.03
# 47                    3124  MARGIE DR, JOELTON, TN     1.03
# 48         2466  UNION HILL RD, GOODLETTSVILLE, TN     2.00
# 49         7221  APPLE VIEW DR, GOODLETTSVILLE, TN     1.35
# 50         7104  LAMA TERRA DR, GOODLETTSVILLE, TN     1.14
# 51         7143  LAMA TERRA DR, GOODLETTSVILLE, TN     1.46
# 52         7175  LAMA TERRA DR, GOODLETTSVILLE, TN     1.77
# 53        6912  RIDGERUNNER CT, GOODLETTSVILLE, TN     0.94
# 54           334  MONCRIEF AVE, GOODLETTSVILLE, TN     1.15
# 55           330  MONCRIEF AVE, GOODLETTSVILLE, TN     0.66
# 56        0  BRICK CHURCH PIKE, GOODLETTSVILLE, TN     8.13
# 57        0  BRICK CHURCH PIKE, GOODLETTSVILLE, TN     3.00
# 58      235  BRICK CHURCH PIKE, GOODLETTSVILLE, TN     3.02
# 59               522  UTLEY DR, GOODLETTSVILLE, TN     1.15
#
#                   TaxDistrict  LandValue  BuildingValue  TotalValue  \
# 0   GENERAL SERVICES DISTRICT    50000.0       168200.0    235700.0
# 1   GENERAL SERVICES DISTRICT    50000.0       264100.0    319000.0
# 2   GENERAL SERVICES DISTRICT    50000.0       216200.0    298000.0
# 3   GENERAL SERVICES DISTRICT    50000.0       147300.0    197300.0
# 4   GENERAL SERVICES DISTRICT    50000.0       152300.0    202300.0
# 5   GENERAL SERVICES DISTRICT    50000.0       190400.0    259800.0
# 6   GENERAL SERVICES DISTRICT    40000.0       137900.0    177900.0
# 7   GENERAL SERVICES DISTRICT    40000.0       157900.0    197900.0
# 8   GENERAL SERVICES DISTRICT    45400.0       176900.0    222300.0
# 9   GENERAL SERVICES DISTRICT    40000.0       179600.0    219600.0
# 10                        NaN        NaN            NaN         NaN
# 11                        NaN        NaN            NaN         NaN
# 12                        NaN        NaN            NaN         NaN
# 13  GENERAL SERVICES DISTRICT    40000.0       203600.0    243600.0
# 14  GENERAL SERVICES DISTRICT    40000.0       115400.0    155400.0
# 15  GENERAL SERVICES DISTRICT    40000.0       180300.0    234000.0
# 16  GENERAL SERVICES DISTRICT    40000.0       129200.0    169200.0
# 17  GENERAL SERVICES DISTRICT    40000.0       127400.0    167400.0
# 18  GENERAL SERVICES DISTRICT    40000.0       286500.0    346300.0
# 19  GENERAL SERVICES DISTRICT    40000.0       130400.0    170400.0
# 20  GENERAL SERVICES DISTRICT    40000.0       238900.0    278900.0
# 21  GENERAL SERVICES DISTRICT    52900.0       330700.0    383600.0
# 22  GENERAL SERVICES DISTRICT    40000.0       158000.0    198000.0
# 23  GENERAL SERVICES DISTRICT    35100.0       116600.0    151700.0
# 24  GENERAL SERVICES DISTRICT    39800.0       112800.0    152600.0
# 25                        NaN        NaN            NaN         NaN
# 26  GENERAL SERVICES DISTRICT    50000.0       119300.0    179200.0
# 27  GENERAL SERVICES DISTRICT    50000.0       134800.0    232300.0
# 28  GENERAL SERVICES DISTRICT    66800.0       140300.0    207100.0
# 29  GENERAL SERVICES DISTRICT    46000.0       153700.0    220900.0
# 30  GENERAL SERVICES DISTRICT    40000.0       333300.0    373300.0
# 31  GENERAL SERVICES DISTRICT    40000.0       169200.0    209200.0
# 32  GENERAL SERVICES DISTRICT    40000.0       133300.0    173300.0
# 33  GENERAL SERVICES DISTRICT    40000.0       148200.0    188200.0
# 34  GENERAL SERVICES DISTRICT    40000.0       143300.0    183300.0
# 35  GENERAL SERVICES DISTRICT    40000.0       104900.0    153400.0
# 36  GENERAL SERVICES DISTRICT    40000.0       138900.0    205600.0
# 37  GENERAL SERVICES DISTRICT    40000.0       126400.0    181100.0
# 38  GENERAL SERVICES DISTRICT    30000.0        64100.0     95700.0
# 39  GENERAL SERVICES DISTRICT    30000.0       148700.0    180000.0
# 40  GENERAL SERVICES DISTRICT    30000.0        94600.0    150500.0
# 41  GENERAL SERVICES DISTRICT    30000.0        97100.0    140700.0
# 42  GENERAL SERVICES DISTRICT    30000.0        88600.0    119300.0
# 43  GENERAL SERVICES DISTRICT    30000.0       111200.0    141200.0
# 44  GENERAL SERVICES DISTRICT    30000.0       111200.0    141200.0
# 45  GENERAL SERVICES DISTRICT    30000.0       115900.0    145900.0
# 46  GENERAL SERVICES DISTRICT    30000.0        83000.0    113000.0
# 47  GENERAL SERVICES DISTRICT    30000.0       116100.0    146100.0
# 48  GENERAL SERVICES DISTRICT    39800.0       134300.0    174100.0
# 49  GENERAL SERVICES DISTRICT    35100.0       173300.0    240100.0
# 50  GENERAL SERVICES DISTRICT    35100.0       147700.0    196200.0
# 51  GENERAL SERVICES DISTRICT    35100.0       134500.0    169600.0
# 52  GENERAL SERVICES DISTRICT    35100.0       121400.0    156500.0
# 53  GENERAL SERVICES DISTRICT    35100.0       144500.0    179600.0
# 54     CITY OF GOODLETTSVILLE    30000.0        97900.0    131000.0
# 55     CITY OF GOODLETTSVILLE    28100.0       107700.0    140800.0
# 56     CITY OF GOODLETTSVILLE    48800.0            0.0     48800.0
# 57     CITY OF GOODLETTSVILLE    45000.0            0.0     45000.0
# 58     CITY OF GOODLETTSVILLE    45100.0       105800.0    150900.0
# 59     CITY OF GOODLETTSVILLE    28100.0       260800.0    288900.0
#
#     YearBuilt  Bedrooms  FullBath  HalfBath
# 0      1986.0       3.0       3.0       0.0
# 1      1998.0       3.0       3.0       2.0
# 2      1987.0       4.0       3.0       0.0
# 3      1985.0       3.0       3.0       0.0
# 4      1984.0       4.0       3.0       0.0
# 5      1980.0       3.0       3.0       0.0
# 6      1976.0       3.0       2.0       0.0
# 7      1978.0       3.0       2.0       0.0
# 8      2000.0       3.0       2.0       1.0
# 9      1995.0       5.0       3.0       0.0
# 10        NaN       NaN       NaN       NaN
# 11        NaN       NaN       NaN       NaN
# 12        NaN       NaN       NaN       NaN
# 13     2006.0       4.0       4.0       0.0
# 14     1974.0       4.0       2.0       0.0
# 15     1974.0       3.0       3.0       0.0
# 16     1974.0       4.0       2.0       0.0
# 17     1974.0       3.0       2.0       0.0
# 18     1974.0       3.0       3.0       1.0
# 19     1986.0       3.0       2.0       1.0
# 20     1985.0       3.0       3.0       0.0
# 21     1997.0       5.0       4.0       1.0
# 22     1989.0       3.0       3.0       0.0
# 23     1988.0       3.0       2.0       0.0
# 24     1982.0       3.0       2.0       0.0
# 25        NaN       NaN       NaN       NaN
# 26     1986.0       2.0       1.0       1.0
# 27     1983.0       3.0       2.0       0.0
# 28     1987.0       3.0       2.0       0.0
# 29     1979.0       3.0       3.0       0.0
# 30     2000.0       4.0       4.0       1.0
# 31     1973.0       3.0       3.0       0.0
# 32     1974.0       3.0       2.0       0.0
# 33     1973.0       3.0       3.0       0.0
# 34     1973.0       3.0       2.0       0.0
# 35     1973.0       3.0       3.0       0.0
# 36     1974.0       3.0       1.0       1.0
# 37     1974.0       3.0       2.0       0.0
# 38     1964.0       3.0       1.0       0.0
# 39     1967.0       3.0       2.0       0.0
# 40     1973.0       3.0       1.0       0.0
# 41     1972.0       3.0       1.0       0.0
# 42     1973.0       3.0       1.0       0.0
# 43     1996.0       3.0       2.0       0.0
# 44     1996.0       3.0       2.0       0.0
# 45     1997.0       3.0       2.0       0.0
# 46     1972.0       3.0       1.0       0.0
# 47     1972.0       4.0       2.0       0.0
# 48     1976.0       3.0       2.0       0.0
# 49     1993.0       3.0       2.0       0.0
# 50     1985.0       3.0       2.0       0.0
# 51     1993.0       3.0       3.0       0.0
# 52     1988.0       3.0       3.0       0.0
# 53     1989.0       3.0       2.0       1.0
# 54     1959.0       3.0       1.0       0.0
# 55     1948.0       3.0       1.0       0.0
# 56        NaN       NaN       NaN       NaN
# 57        NaN       NaN       NaN       NaN
# 58     1984.0       4.0       3.0       0.0
# 59     1995.0       4.0       3.0       0.0

# %%
data.shape
# Out:
# (56477, 19)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56477 entries, 0 to 56476
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   UniqueID         56477 non-null  int64
#  1   ParcelID         56477 non-null  object
#  2   LandUse          56477 non-null  object
#  3   PropertyAddress  56448 non-null  object
#  4   SaleDate         56477 non-null  object
#  5   SalePrice        56477 non-null  object
#  6   LegalReference   56477 non-null  object
#  7   SoldAsVacant     56477 non-null  object
#  8   OwnerName        25261 non-null  object
#  9   OwnerAddress     26015 non-null  object
#  10  Acreage          26015 non-null  float64
#  11  TaxDistrict      26015 non-null  object
#  12  LandValue        26015 non-null  float64
#  13  BuildingValue    26015 non-null  float64
#  14  TotalValue       26015 non-null  float64
#  15  YearBuilt        24163 non-null  float64
#  16  Bedrooms         24157 non-null  float64
#  17  FullBath         24275 non-null  float64
#  18  HalfBath         24144 non-null  float64
# dtypes: float64(8), int64(1), object(10)
# memory usage: 8.2+ MB

# %%
data.columns
# Out:
# Index(['UniqueID ', 'ParcelID', 'LandUse', 'PropertyAddress', 'SaleDate',
#        'SalePrice', 'LegalReference', 'SoldAsVacant', 'OwnerName',
#        'OwnerAddress', 'Acreage', 'TaxDistrict', 'LandValue', 'BuildingValue',
#        'TotalValue', 'YearBuilt', 'Bedrooms', 'FullBath', 'HalfBath'],
#       dtype='object')

# %%
house_sales= data[['UniqueID ','ParcelID','LandUse','PropertyAddress','SaleDate','SalePrice','LegalReference','SoldAsVacant']]
prop_detail = data[['OwnerName','OwnerAddress','Acreage','TaxDistrict','LandValue', 'BuildingValue',
       'TotalValue', 'YearBuilt', 'Bedrooms', 'FullBath', 'HalfBath']]

# %%
house_sales.isna().sum()
# Out:
# UniqueID            0
# ParcelID            0
# LandUse             0
# PropertyAddress    29
# SaleDate            0
# SalePrice           0
# LegalReference      0
# SoldAsVacant        0
# dtype: int64

# %%
house_sales.shape
# Out:
# (56477, 8)

# %%
house_sales[house_sales['PropertyAddress'].isnull()== True].head()
# Out:
#      UniqueID           ParcelID                  LandUse PropertyAddress  \
# 159      43076   025 07 0 031.00            SINGLE FAMILY             NaN
# 223      39432   026 01 0 069.00  VACANT RESIDENTIAL LAND             NaN
# 246      45290   026 05 0 017.00            SINGLE FAMILY             NaN
# 305      53147  026 06 0A 038.00        RESIDENTIAL CONDO             NaN
# 531      43080   033 06 0 041.00            SINGLE FAMILY             NaN
#
#              SaleDate SalePrice    LegalReference SoldAsVacant
# 159  January 15, 2016    179900  20160120-0005776           No
# 223  October 23, 2015    153000  20151028-0109602           No
# 246    March 29, 2016    155000  20160330-0029941           No
# 305   August 25, 2016    144900  20160831-0091567           No
# 531   January 4, 2016    170000  20160107-0001526           No

# %%
prop_detail.isna().sum()
# Out:
# OwnerName        31216
# OwnerAddress     30462
# Acreage          30462
# TaxDistrict      30462
# LandValue        30462
# BuildingValue    30462
# TotalValue       30462
# YearBuilt        32314
# Bedrooms         32320
# FullBath         32202
# HalfBath         32333
# dtype: int64

# %%
prop_detail[prop_detail['OwnerName'].isna()==True].head(20)
# Out:
#     OwnerName OwnerAddress  Acreage TaxDistrict  LandValue  BuildingValue  \
# 10        NaN          NaN      NaN         NaN        NaN            NaN
# 11        NaN          NaN      NaN         NaN        NaN            NaN
# 12        NaN          NaN      NaN         NaN        NaN            NaN
# 25        NaN          NaN      NaN         NaN        NaN            NaN
# 108       NaN          NaN      NaN         NaN        NaN            NaN
# 109       NaN          NaN      NaN         NaN        NaN            NaN
# 110       NaN          NaN      NaN         NaN        NaN            NaN
# 111       NaN          NaN      NaN         NaN        NaN            NaN
# 112       NaN          NaN      NaN         NaN        NaN            NaN
# 113       NaN          NaN      NaN         NaN        NaN            NaN
# 114       NaN          NaN      NaN         NaN        NaN            NaN
# 115       NaN          NaN      NaN         NaN        NaN            NaN
# 116       NaN          NaN      NaN         NaN        NaN            NaN
# 117       NaN          NaN      NaN         NaN        NaN            NaN
# 118       NaN          NaN      NaN         NaN        NaN            NaN
# 119       NaN          NaN      NaN         NaN        NaN            NaN
# 120       NaN          NaN      NaN         NaN        NaN            NaN
# 121       NaN          NaN      NaN         NaN        NaN            NaN
# 122       NaN          NaN      NaN         NaN        NaN            NaN
# 292       NaN          NaN      NaN         NaN        NaN            NaN
#
#      TotalValue  YearBuilt  Bedrooms  FullBath  HalfBath
# 10          NaN        NaN       NaN       NaN       NaN
# 11          NaN        NaN       NaN       NaN       NaN
# 12          NaN        NaN       NaN       NaN       NaN
# 25          NaN        NaN       NaN       NaN       NaN
# 108         NaN        NaN       NaN       NaN       NaN
# 109         NaN        NaN       NaN       NaN       NaN
# 110         NaN        NaN       NaN       NaN       NaN
# 111         NaN        NaN       NaN       NaN       NaN
# 112         NaN        NaN       NaN       NaN       NaN
# 113         NaN        NaN       NaN       NaN       NaN
# 114         NaN        NaN       NaN       NaN       NaN
# 115         NaN        NaN       NaN       NaN       NaN
# 116         NaN        NaN       NaN       NaN       NaN
# 117         NaN        NaN       NaN       NaN       NaN
# 118         NaN        NaN       NaN       NaN       NaN
# 119         NaN        NaN       NaN       NaN       NaN
# 120         NaN        NaN       NaN       NaN       NaN
# 121         NaN        NaN       NaN       NaN       NaN
# 122         NaN        NaN       NaN       NaN       NaN
# 292         NaN        NaN       NaN       NaN       NaN

# %%
df = data[['PropertyAddress','LandUse','Bedrooms','FullBath','HalfBath','Acreage','LandValue','BuildingValue','TotalValue','SalePrice','SoldAsVacant','YearBuilt','SaleDate']]

# %%
df.head()
# Out:
#                       PropertyAddress        LandUse  Bedrooms  FullBath  \
# 0  1808  FOX CHASE DR, GOODLETTSVILLE  SINGLE FAMILY       3.0       3.0
# 1  1832  FOX CHASE DR, GOODLETTSVILLE  SINGLE FAMILY       3.0       3.0
# 2  1864 FOX CHASE  DR, GOODLETTSVILLE  SINGLE FAMILY       4.0       3.0
# 3  1853  FOX CHASE DR, GOODLETTSVILLE  SINGLE FAMILY       3.0       3.0
# 4  1829  FOX CHASE DR, GOODLETTSVILLE  SINGLE FAMILY       4.0       3.0
#
#    HalfBath  Acreage  LandValue  BuildingValue  TotalValue SalePrice  \
# 0       0.0      2.3    50000.0       168200.0    235700.0    240000
# 1       2.0      3.5    50000.0       264100.0    319000.0    366000
# 2       0.0      2.9    50000.0       216200.0    298000.0    435000
# 3       0.0      2.6    50000.0       147300.0    197300.0    255000
# 4       0.0      2.0    50000.0       152300.0    202300.0    278000
#
#   SoldAsVacant  YearBuilt            SaleDate
# 0           No     1986.0       April 9, 2013
# 1           No     1998.0       June 10, 2014
# 2           No     1987.0  September 26, 2016
# 3           No     1985.0    January 29, 2016
# 4           No     1984.0    October 10, 2014

# %% [markdown]
# ## Convert YearBuilt and SaleDate to a datetime

# %%
df['YearBuilt'] = df['YearBuilt'].fillna(0)
# Out:
# C:\Users\Jessie Nae\AppData\Local\Temp\ipykernel_21724\1239092472.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['YearBuilt'] = df['YearBuilt'].fillna(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56477 entries, 0 to 56476
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   PropertyAddress  56448 non-null  object
#  1   LandUse          56477 non-null  object
#  2   Bedrooms         24157 non-null  float64
#  3   FullBath         24275 non-null  float64
#  4   HalfBath         24144 non-null  float64
#  5   Acreage          26015 non-null  float64
#  6   LandValue        26015 non-null  float64
#  7   BuildingValue    26015 non-null  float64
#  8   TotalValue       26015 non-null  float64
#  9   SalePrice        56477 non-null  object
#  10  SoldAsVacant     56477 non-null  object
#  11  YearBuilt        56477 non-null  float64
#  12  SaleDate         56477 non-null  object
# dtypes: float64(8), object(5)
# memory usage: 5.6+ MB

# %%
df['YearBuilt'] = df['YearBuilt'].astype('int')
# Out:
# C:\Users\Jessie Nae\AppData\Local\Temp\ipykernel_21724\190402565.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['YearBuilt'] = df['YearBuilt'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56477 entries, 0 to 56476
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   PropertyAddress  56448 non-null  object
#  1   LandUse          56477 non-null  object
#  2   Bedrooms         24157 non-null  float64
#  3   FullBath         24275 non-null  float64
#  4   HalfBath         24144 non-null  float64
#  5   Acreage          26015 non-null  float64
#  6   LandValue        26015 non-null  float64
#  7   BuildingValue    26015 non-null  float64
#  8   TotalValue       26015 non-null  float64
#  9   SalePrice        56477 non-null  object
#  10  SoldAsVacant     56477 non-null  object
#  11  YearBuilt        56477 non-null  int32
#  12  SaleDate         56477 non-null  object
# dtypes: float64(7), int32(1), object(5)
# memory usage: 5.4+ MB

# %%
df.head()
# Out:
#                       PropertyAddress        LandUse  Bedrooms  FullBath  \
# 0  1808  FOX CHASE DR, GOODLETTSVILLE  SINGLE FAMILY       3.0       3.0
# 1  1832  FOX CHASE DR, GOODLETTSVILLE  SINGLE FAMILY       3.0       3.0
# 2  1864 FOX CHASE  DR, GOODLETTSVILLE  SINGLE FAMILY       4.0       3.0
# 3  1853  FOX CHASE DR, GOODLETTSVILLE  SINGLE FAMILY       3.0       3.0
# 4  1829  FOX CHASE DR, GOODLETTSVILLE  SINGLE FAMILY       4.0       3.0
#
#    HalfBath  Acreage  LandValue  BuildingValue  TotalValue SalePrice  \
# 0       0.0      2.3    50000.0       168200.0    235700.0    240000
# 1       2.0      3.5    50000.0       264100.0    319000.0    366000
# 2       0.0      2.9    50000.0       216200.0    298000.0    435000
# 3       0.0      2.6    50000.0       147300.0    197300.0    255000
# 4       0.0      2.0    50000.0       152300.0    202300.0    278000
#
#   SoldAsVacant  YearBuilt            SaleDate
# 0           No       1986       April 9, 2013
# 1           No       1998       June 10, 2014
# 2           No       1987  September 26, 2016
# 3           No       1985    January 29, 2016
# 4           No       1984    October 10, 2014

# %%
df['SaleDate'] = pd.to_datetime(df['SaleDate']).dt.year
# Out:
# C:\Users\Jessie Nae\AppData\Local\Temp\ipykernel_21724\2640389723.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['SaleDate'] = pd.to_datetime(df['SaleDate']).dt.year

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56477 entries, 0 to 56476
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   PropertyAddress  56448 non-null  object
#  1   LandUse          56477 non-null  object
#  2   Bedrooms         24157 non-null  float64
#  3   FullBath         24275 non-null  float64
#  4   HalfBath         24144 non-null  float64
#  5   Acreage          26015 non-null  float64
#  6   LandValue        26015 non-null  float64
#  7   BuildingValue    26015 non-null  float64
#  8   TotalValue       26015 non-null  float64
#  9   SalePrice        56477 non-null  object
#  10  SoldAsVacant     56477 non-null  object
#  11  YearBuilt        56477 non-null  int32
#  12  SaleDate         56477 non-null  int64
# dtypes: float64(7), int32(1), int64(1), object(4)
# memory usage: 5.4+ MB

# %%
df.head()
# Out:
#                       PropertyAddress        LandUse  Bedrooms  FullBath  \
# 0  1808  FOX CHASE DR, GOODLETTSVILLE  SINGLE FAMILY       3.0       3.0
# 1  1832  FOX CHASE DR, GOODLETTSVILLE  SINGLE FAMILY       3.0       3.0
# 2  1864 FOX CHASE  DR, GOODLETTSVILLE  SINGLE FAMILY       4.0       3.0
# 3  1853  FOX CHASE DR, GOODLETTSVILLE  SINGLE FAMILY       3.0       3.0
# 4  1829  FOX CHASE DR, GOODLETTSVILLE  SINGLE FAMILY       4.0       3.0
#
#    HalfBath  Acreage  LandValue  BuildingValue  TotalValue SalePrice  \
# 0       0.0      2.3    50000.0       168200.0    235700.0    240000
# 1       2.0      3.5    50000.0       264100.0    319000.0    366000
# 2       0.0      2.9    50000.0       216200.0    298000.0    435000
# 3       0.0      2.6    50000.0       147300.0    197300.0    255000
# 4       0.0      2.0    50000.0       152300.0    202300.0    278000
#
#   SoldAsVacant  YearBuilt  SaleDate
# 0           No       1986      2013
# 1           No       1998      2014
# 2           No       1987      2016
# 3           No       1985      2016
# 4           No       1984      2014

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56477 entries, 0 to 56476
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   PropertyAddress  56448 non-null  object
#  1   LandUse          56477 non-null  object
#  2   Bedrooms         24157 non-null  float64
#  3   FullBath         24275 non-null  float64
#  4   HalfBath         24144 non-null  float64
#  5   Acreage          26015 non-null  float64
#  6   LandValue        26015 non-null  float64
#  7   BuildingValue    26015 non-null  float64
#  8   TotalValue       26015 non-null  float64
#  9   SalePrice        56477 non-null  object
#  10  SoldAsVacant     56477 non-null  object
#  11  YearBuilt        56477 non-null  int32
#  12  SaleDate         56477 non-null  int64
# dtypes: float64(7), int32(1), int64(1), object(4)
# memory usage: 5.4+ MB

# %% [markdown]
# ## Convert SalePrice to float

# %%
# df['SalePrice'] = df['SalePrice'].str.replace(',','').astype('float')

# %%
# df[df['SalePrice'] == '$120000 ']

# %%
df['SalePrice'] = df['SalePrice'].str.replace(' ','')
# Out:
# C:\Users\Jessie Nae\AppData\Local\Temp\ipykernel_21724\426259618.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['SalePrice'] = df['SalePrice'].str.replace(' ','')

# %%
df['SalePrice'] = df['SalePrice'].str.replace('$','')
# Out:
# C:\Users\Jessie Nae\AppData\Local\Temp\ipykernel_21724\1253375716.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['SalePrice'] = df['SalePrice'].str.replace('$','')
# C:\Users\Jessie Nae\AppData\Local\Temp\ipykernel_21724\1253375716.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['SalePrice'] = df['SalePrice'].str.replace('$','')

# %%
# df[df['SalePrice'] == '$120000 ']

# %%
df['SalePrice'] = df['SalePrice'].astype('float')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 df['SalePrice'] = df['SalePrice'].astype('float')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:448, in BaseBlockManager.astype(self, dtype, copy, errors)
#     447 def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 448     return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:352, in BaseBlockManager.apply(self, f, align_keys, ignore_failures, **kwargs)
#     350         applied = b.apply(f, **kwargs)
#     351     else:
# --> 352         applied = getattr(b, f)(**kwargs)
#     353 except (TypeError, NotImplementedError):
#     354     if not ignore_failures:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:526, in Block.astype(self, dtype, copy, errors)
#     508 """
#     509 Coerce to the new dtype.
#     510
#    (...)
#     522 Block
#     523 """
#     524 values = self.values
# --> 526 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     528 new_values = maybe_coerce_values(new_values)
#     529 newb = self.make_block(new_values)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\dtypes\astype.py:299, in astype_array_safe(values, dtype, copy, errors)
#     296     return values.copy()
#     298 try:
# --> 299     new_values = astype_array(values, dtype, copy=copy)
#     300 except (ValueError, TypeError):
#     301     # e.g. astype_nansafe can fail on object-dtype of strings
#     302     #  trying to convert to float
#     303     if errors == "ignore":
#
# File ~\anaconda3\Lib\site-packages\pandas\core\dtypes\astype.py:230, in astype_array(values, dtype, copy)
#     227     values = values.astype(dtype, copy=copy)
#     229 else:
# --> 230     values = astype_nansafe(values, dtype, copy=copy)
#     232 # in pandas we don't store numpy str dtypes, so convert to object
#     233 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\dtypes\astype.py:170, in astype_nansafe(arr, dtype, copy, skipna)
#     166     raise ValueError(msg)
#     168 if copy or is_object_dtype(arr.dtype) or is_object_dtype(dtype):
#     169     # Explicit copy, or required since NumPy can't view from / to object.
# --> 170     return arr.astype(dtype, copy=True)
#     172 return arr.astype(dtype, copy=copy)
#
# ValueError: could not convert string to float: '120,000'

# %%
df.info()

# %%
df.head()

# %% [markdown]
# ## Convert float to an integer

# %%
df[['Bedrooms','FullBath','HalfBath']] = df[['Bedrooms','FullBath','HalfBath']].fillna(0)

# %%
df.info()

# %%
df[['Bedrooms','FullBath','HalfBath']] = df[['Bedrooms','FullBath','HalfBath']].astype('int')

# %% [markdown]
# ## Learn how to have a 2decimal places float datatype!!!

# %%
df.head()

# %%
df['SoldAsVacant'].unique() #write a function that converts 'Y' to 'Yes' and 'N' to 'No'

# %%
# Check what is wrong with the code

# def correct(syn):
#     for i in df['SoldAsVacant']:
#         if i == 'N':
#             print('No')
#         elif i == 'Y':
#             print('Yes')
#     return i

#Code enters an infinite loop,why??

# %%
df['SoldAsVacant'] = df['SoldAsVacant'].replace({'Y':'Yes','N':'No'})

# %%
df['SoldAsVacant'].unique()

# %%
df.info()

# %%
df.head()

# %% [markdown]
# ### Q1 : Does 'Acreage' affect the 'sale price' of the property??(WHO)
# ## answer... what is their relationship and what visualization would depict the meaning?

# %% [markdown]
# ### Q2 : What is the most expensive property and why is it so??

# %%
df[df['PropertyAddress'].duplicated()]['PropertyAddress']

# %%
df['SalePrice'].max()['']

# %%
df[df['SalePrice']==54278060.0][['PropertyAddress','LandUse','LandValue','BuildingValue','SalePrice']]

# %% [markdown]
# ### How many properties were sold each year??
# ### Answer: In each unique year, I wanna know how many property was sold(in relation with 'PropertyAddress' )

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # Understand how count and groupby works
# ### Verify how to plot just one column in a pandas dataframe against the groupby and count function

# %%
# grouped = df.groupby('SaleDate').count()

# %%
grouped.plot(kind='bar')

# %%
df['LandUse'].replace({'VACANT RESIENTIAL LAND':'VACANT RESIDENTIAL LAND'},inplace=True)

# %%
len(df['LandUse'].unique())

# %% [markdown]
# ## Q4: Was there a circumstance when the 'total price' is greater than the 'sale price' of a property??
#
# ## Answer : Yes,about 6427 properties ,meaning that certain losses were incurred OR

# %%
df[df['TotalValue']>df['SalePrice']]

# %% [markdown]
# #### Q6.. What is the difference between 'the year the property was built ' and 'the year the property was sold'??

# %%
df['year_diff'] = df['SaleDate'] - df['YearBuilt']
